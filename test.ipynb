# %%
import numpy
import tensorflow as tf
import os
import pandas as pd
print(tf.version)
# Out:
# WARNING:tensorflow:From d:\SharedNB\Coding\a66\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# <module 'tensorflow._api.v2.version' from 'd:\\SharedNB\\Coding\\a66\\.venv\\Lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>
